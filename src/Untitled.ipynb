# %%
import pickle
import cv2
import pandas as pd
from matplotlib.pyplot import imshow
from matplotlib import pyplot as plt

# %%
# !ls
# Out:
# AlexNet.ipynb  ground_truth		     README.md	       Untitled.ipynb
# assets	       images			     requirements.txt  valid.json
# data_annote    mpii_human_pose_v1_u12_1.mat  show_im.py        venv
# FLIC	       mpii_human_pose_v1_u12_2      train.json        white.email

# %%
with open('ground_truth', 'rb') as file:
    data = pickle.load(file)

# %%
coord_x = data[0][0][0]
coord_y = data[0][0][29]

# %%
im_path = "FLIC/images/12-oclock-high-special-edition-00006361.jpg"

# %%
image = cv2.imread(im_path)

fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(image)

ax.scatter(x=coord_x,y=coord_y,s=100,lw=5,facecolor="none",edgecolor="yellow")

# %%
coord_y
# Out:
# 213.3125
